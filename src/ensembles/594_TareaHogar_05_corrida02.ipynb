# %% [markdown]
# <a href="https://colab.research.google.com/github/keiverdatascience/labo2025v/blob/main/src/ensembles/594_TareaHogar_05_corrida02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 05 12:20:21 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660356 35.3 1454482    77.7 1454482  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5941
PARAM$semilla_primigenia <- 245681

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate",        lower = 0.005, upper = 0.2),
  makeIntegerParam("num_leaves",           lower = 8L,    upper = 256L),
  makeIntegerParam("min_data_in_leaf",     lower = 200L,  upper = 5000L),
  makeNumericParam("feature_fraction",     lower = 0.05,  upper = 0.4),
  makeNumericParam("min_gain_to_split",    lower = 0.0,   upper = 5.0)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83658
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 05 12:37:20 AM 2025 AUC 0.924270857975495
#
# Wed Nov 05 12:39:29 AM 2025 AUC 0.925098718377461
#
# Wed Nov 05 12:42:16 AM 2025 AUC 0.924848597474089
#
# Wed Nov 05 12:44:49 AM 2025 AUC 0.92015082553534
#
# Wed Nov 05 12:46:58 AM 2025 AUC 0.923996914642997
#
# Wed Nov 05 12:49:52 AM 2025 AUC 0.922310517458082
#
# Wed Nov 05 12:52:19 AM 2025 AUC 0.923757476017099
#
# Wed Nov 05 12:54:14 AM 2025 AUC 0.923621454086297
#
# Wed Nov 05 12:56:10 AM 2025 AUC 0.925637915637538
#
# Wed Nov 05 12:58:55 AM 2025 AUC 0.923141620014894
#
# Wed Nov 05 01:01:39 AM 2025 AUC 0.928451858367238
#
# Wed Nov 05 01:03:51 AM 2025 AUC 0.92331960045483
#
# Wed Nov 05 01:06:09 AM 2025 AUC 0.923531423682399
#
# Wed Nov 05 01:08:40 AM 2025 AUC 0.923743932818743
#
# Wed Nov 05 01:10:58 AM 2025 AUC 0.92100020724254
#
# Wed Nov 05 01:14:07 AM 2025 AUC 0.923181664249843
#
# Wed Nov 05 01:17:07 AM 2025 AUC 0.923147004122533
#
# Wed Nov 05 01:20:55 AM 2025 AUC 0.929075084493615
#
# Wed Nov 05 01:23:08 AM 2025 AUC 0.925180461069551
#
# Wed Nov 05 01:25:20 AM 2025 AUC 0.923370862763887
#
# [mbo] 0: learning_rate=0.11; num_leaves=130; min_data_in_leaf=2078; feature_fraction=0.376; min_gain_to_split=2.68 : y = 0.924 : 177.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.15; num_leaves=174; min_data_in_leaf=1571; feature_fraction=0.127; min_gain_to_split=2.89 : y = 0.925 : 128.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0655; num_leaves=144; min_data_in_leaf=1672; feature_fraction=0.319; min_gain_to_split=4.36 : y = 0.925 : 167.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.166; num_leaves=15; min_data_in_leaf=3777; feature_fraction=0.246; min_gain_to_split=4.69 : y = 0.92 : 152.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0278; num_leaves=245; min_data_in_leaf=3146; feature_fraction=0.0982; min_gain_to_split=1.66 : y = 0.924 : 129.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.134; num_leaves=194; min_data_in_leaf=2572; feature_fraction=0.362; min_gain_to_split=3.8 : y = 0.922 : 173.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0938; num_leaves=58; min_data_in_leaf=2162; feature_fraction=0.224; min_gain_to_split=3.19 : y = 0.924 : 147.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0748; num_leaves=198; min_data_in_leaf=3000; feature_fraction=0.0649; min_gain_to_split=0.398 : y = 0.924 : 114.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.117; num_leaves=25; min_data_in_leaf=2837; feature_fraction=0.0828; min_gain_to_split=1.25 : y = 0.926 : 116.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0484; num_leaves=103; min_data_in_leaf=4706; feature_fraction=0.291; min_gain_to_split=1.75 : y = 0.923 : 164.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.088; num_leaves=145; min_data_in_leaf=615; feature_fraction=0.311; min_gain_to_split=2.24 : y = 0.928 : 164.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.191; num_leaves=89; min_data_in_leaf=4088; feature_fraction=0.154; min_gain_to_split=0.632 : y = 0.923 : 132.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0588; num_leaves=109; min_data_in_leaf=1001; feature_fraction=0.181; min_gain_to_split=4.84 : y = 0.924 : 137.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.156; num_leaves=42; min_data_in_leaf=354; feature_fraction=0.24; min_gain_to_split=0.834 : y = 0.924 : 150.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.174; num_leaves=235; min_data_in_leaf=4478; feature_fraction=0.193; min_gain_to_split=3.63 : y = 0.921 : 137.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.00992; num_leaves=228; min_data_in_leaf=3957; feature_fraction=0.346; min_gain_to_split=3.41 : y = 0.923 : 189.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.126; num_leaves=74; min_data_in_leaf=3352; feature_fraction=0.394; min_gain_to_split=2.49 : y = 0.923 : 180.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0225; num_leaves=219; min_data_in_leaf=1161; feature_fraction=0.266; min_gain_to_split=0.0297 : y = 0.929 : 227.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.181; num_leaves=164; min_data_in_leaf=781; feature_fraction=0.163; min_gain_to_split=4.21 : y = 0.925 : 133.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0417; num_leaves=45; min_data_in_leaf=4781; feature_fraction=0.12; min_gain_to_split=1.44 : y = 0.923 : 132.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Wed Nov 05 01:28:24 AM 2025 AUC 0.929477853324856
#
# [mbo] 1: learning_rate=0.0322; num_leaves=217; min_data_in_leaf=672; feature_fraction=0.303; min_gain_to_split=0.748 : y = 0.929 : 183.0 secs : infill_ei
#
# Wed Nov 05 01:32:15 AM 2025 AUC 0.930958840781912
#
# [mbo] 2: learning_rate=0.00509; num_leaves=206; min_data_in_leaf=305; feature_fraction=0.286; min_gain_to_split=1.63 : y = 0.931 : 230.9 secs : infill_ei
#
# Wed Nov 05 01:36:03 AM 2025 AUC 0.929840154717271
#
# [mbo] 3: learning_rate=0.00523; num_leaves=251; min_data_in_leaf=205; feature_fraction=0.278; min_gain_to_split=2.03 : y = 0.93 : 227.1 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Wed Nov 05 01:39:52 AM 2025 AUC 0.930049728041939
#
# [mbo] 4: learning_rate=0.00501; num_leaves=186; min_data_in_leaf=201; feature_fraction=0.27; min_gain_to_split=1.68 : y = 0.93 : 228.8 secs : infill_ei
#
# Wed Nov 05 01:43:55 AM 2025 AUC 0.929462511726787
#
# [mbo] 5: learning_rate=0.00513; num_leaves=211; min_data_in_leaf=404; feature_fraction=0.349; min_gain_to_split=2.2 : y = 0.929 : 241.6 secs : infill_ei
#
# Wed Nov 05 01:47:47 AM 2025 AUC 0.93044020293876
#
# [mbo] 6: learning_rate=0.0051; num_leaves=192; min_data_in_leaf=400; feature_fraction=0.299; min_gain_to_split=1.76 : y = 0.93 : 231.4 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Wed Nov 05 01:51:21 AM 2025 AUC 0.930860135094291
#
# [mbo] 7: learning_rate=0.00556; num_leaves=230; min_data_in_leaf=540; feature_fraction=0.267; min_gain_to_split=1.55 : y = 0.931 : 213.3 secs : infill_ei
#
# Wed Nov 05 01:54:50 AM 2025 AUC 0.930332071422182
#
# [mbo] 8: learning_rate=0.00625; num_leaves=213; min_data_in_leaf=456; feature_fraction=0.272; min_gain_to_split=1.83 : y = 0.93 : 208.8 secs : infill_ei
#
# Wed Nov 05 01:57:38 AM 2025 AUC 0.929603584030451
#
# [mbo] 9: learning_rate=0.0674; num_leaves=231; min_data_in_leaf=329; feature_fraction=0.303; min_gain_to_split=1.51 : y = 0.93 : 166.8 secs : infill_ei
#
# Wed Nov 05 02:01:29 AM 2025 AUC 0.931692843586192
#
# [mbo] 10: learning_rate=0.00539; num_leaves=256; min_data_in_leaf=340; feature_fraction=0.295; min_gain_to_split=1.36 : y = 0.932 : 230.5 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Wed Nov 05 02:05:43 AM 2025 AUC 0.929229646286425
#
# [mbo] 11: learning_rate=0.00513; num_leaves=249; min_data_in_leaf=314; feature_fraction=0.354; min_gain_to_split=1.26 : y = 0.929 : 253.8 secs : infill_ei
#
# Wed Nov 05 02:09:34 AM 2025 AUC 0.930539625354107
#
# [mbo] 12: learning_rate=0.0054; num_leaves=254; min_data_in_leaf=516; feature_fraction=0.287; min_gain_to_split=1.25 : y = 0.931 : 230.0 secs : infill_ei
#
# Wed Nov 05 02:12:37 AM 2025 AUC 0.930819789680348
#
# [mbo] 13: learning_rate=0.016; num_leaves=256; min_data_in_leaf=326; feature_fraction=0.277; min_gain_to_split=1.44 : y = 0.931 : 182.2 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Wed Nov 05 02:17:00 AM 2025 AUC 0.930583284891903
#
# [mbo] 14: learning_rate=0.00503; num_leaves=241; min_data_in_leaf=302; feature_fraction=0.299; min_gain_to_split=0.672 : y = 0.931 : 262.7 secs : infill_ei
#
# Wed Nov 05 02:20:42 AM 2025 AUC 0.928685532757763
#
# [mbo] 15: learning_rate=0.00674; num_leaves=255; min_data_in_leaf=992; feature_fraction=0.304; min_gain_to_split=1.5 : y = 0.929 : 221.2 secs : infill_ei
#
# Wed Nov 05 02:23:47 AM 2025 AUC 0.930109067434709
#
# [mbo] 16: learning_rate=0.0188; num_leaves=221; min_data_in_leaf=207; feature_fraction=0.294; min_gain_to_split=1.35 : y = 0.93 : 184.6 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Wed Nov 05 02:27:32 AM 2025 AUC 0.930293097708911
#
# [mbo] 17: learning_rate=0.00507; num_leaves=232; min_data_in_leaf=359; feature_fraction=0.244; min_gain_to_split=1.39 : y = 0.93 : 225.0 secs : infill_ei
#
# Wed Nov 05 02:30:58 AM 2025 AUC 0.931366325529675
#
# [mbo] 18: learning_rate=0.00702; num_leaves=228; min_data_in_leaf=726; feature_fraction=0.253; min_gain_to_split=1.56 : y = 0.931 : 205.4 secs : infill_ei
#
# Wed Nov 05 02:33:38 AM 2025 AUC 0.927168020234556
#
# [mbo] 19: learning_rate=0.0784; num_leaves=243; min_data_in_leaf=212; feature_fraction=0.261; min_gain_to_split=1.36 : y = 0.927 : 159.1 secs : infill_ei
#
# Wed Nov 05 02:36:51 AM 2025 AUC 0.928381101729828
#
# [mbo] 20: learning_rate=0.00506; num_leaves=202; min_data_in_leaf=767; feature_fraction=0.228; min_gain_to_split=2.28 : y = 0.928 : 192.3 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Wed Nov 05 02:40:36 AM 2025 AUC 0.930027881059959
#
# [mbo] 21: learning_rate=0.00541; num_leaves=228; min_data_in_leaf=754; feature_fraction=0.262; min_gain_to_split=1.04 : y = 0.93 : 224.2 secs : infill_ei
#
# Wed Nov 05 02:43:15 AM 2025 AUC 0.928632400651909
#
# [mbo] 22: learning_rate=0.0526; num_leaves=237; min_data_in_leaf=846; feature_fraction=0.255; min_gain_to_split=1.61 : y = 0.929 : 159.2 secs : infill_ei
#
# Wed Nov 05 02:46:14 AM 2025 AUC 0.92993042800201
#
# [mbo] 23: learning_rate=0.0516; num_leaves=254; min_data_in_leaf=688; feature_fraction=0.35; min_gain_to_split=1.98 : y = 0.93 : 178.0 secs : infill_ei
#
# Wed Nov 05 02:49:13 AM 2025 AUC 0.930750817084231
#
# [mbo] 24: learning_rate=0.0144; num_leaves=255; min_data_in_leaf=630; feature_fraction=0.253; min_gain_to_split=1.56 : y = 0.931 : 178.3 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Wed Nov 05 02:52:31 AM 2025 AUC 0.92708450185066
#
# [mbo] 25: learning_rate=0.00521; num_leaves=204; min_data_in_leaf=1273; feature_fraction=0.243; min_gain_to_split=1.6 : y = 0.927 : 198.0 secs : infill_ei
#
# Wed Nov 05 02:56:10 AM 2025 AUC 0.929287275722994
#
# [mbo] 26: learning_rate=0.00516; num_leaves=243; min_data_in_leaf=691; feature_fraction=0.295; min_gain_to_split=1.81 : y = 0.929 : 218.6 secs : infill_ei
#
# Wed Nov 05 02:59:08 AM 2025 AUC 0.92876049030126
#
# [mbo] 27: learning_rate=0.0496; num_leaves=256; min_data_in_leaf=205; feature_fraction=0.322; min_gain_to_split=0.932 : y = 0.929 : 176.9 secs : infill_ei
#
# Wed Nov 05 03:02:39 AM 2025 AUC 0.929281796389141
#
# [mbo] 28: learning_rate=0.0139; num_leaves=236; min_data_in_leaf=295; feature_fraction=0.261; min_gain_to_split=0.472 : y = 0.929 : 211.0 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Wed Nov 05 03:06:38 AM 2025 AUC 0.930530911503205
#
# [mbo] 29: learning_rate=0.00501; num_leaves=256; min_data_in_leaf=324; feature_fraction=0.31; min_gain_to_split=1.46 : y = 0.931 : 237.8 secs : infill_ei
#
# Wed Nov 05 03:09:42 AM 2025 AUC 0.930242722899695
#
# [mbo] 30: learning_rate=0.0122; num_leaves=115; min_data_in_leaf=674; feature_fraction=0.252; min_gain_to_split=1.52 : y = 0.93 : 183.9 secs : infill_ei
#
# Wed Nov 05 03:12:54 AM 2025 AUC 0.927098908753734
#
# [mbo] 31: learning_rate=0.0675; num_leaves=231; min_data_in_leaf=968; feature_fraction=0.339; min_gain_to_split=0.203 : y = 0.927 : 191.4 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Wed Nov 05 03:15:46 AM 2025 AUC 0.927654179347997
#
# [mbo] 32: learning_rate=0.0194; num_leaves=252; min_data_in_leaf=353; feature_fraction=0.291; min_gain_to_split=4.03 : y = 0.928 : 170.8 secs : infill_ei
#
# Wed Nov 05 03:19:28 AM 2025 AUC 0.930684358079817
#
# [mbo] 33: learning_rate=0.00519; num_leaves=118; min_data_in_leaf=240; feature_fraction=0.284; min_gain_to_split=1.69 : y = 0.931 : 221.2 secs : infill_ei
#
# Wed Nov 05 03:22:26 AM 2025 AUC 0.929364534551582
#
# [mbo] 34: learning_rate=0.05; num_leaves=103; min_data_in_leaf=476; feature_fraction=0.344; min_gain_to_split=1.32 : y = 0.929 : 177.7 secs : infill_ei
#
# Wed Nov 05 03:26:39 AM 2025 AUC 0.930704647710934
#
# [mbo] 35: learning_rate=0.00507; num_leaves=110; min_data_in_leaf=362; feature_fraction=0.296; min_gain_to_split=0.77 : y = 0.931 : 252.2 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Wed Nov 05 03:31:19 AM 2025 AUC 0.929886833754979
#
# [mbo] 36: learning_rate=0.00523; num_leaves=153; min_data_in_leaf=202; feature_fraction=0.287; min_gain_to_split=0.186 : y = 0.93 : 279.1 secs : infill_ei
#
# Wed Nov 05 03:34:38 AM 2025 AUC 0.92992879802904
#
# [mbo] 37: learning_rate=0.00856; num_leaves=215; min_data_in_leaf=415; feature_fraction=0.259; min_gain_to_split=1.45 : y = 0.93 : 198.4 secs : infill_ei
#
# Wed Nov 05 03:37:31 AM 2025 AUC 0.928929864801101
#
# [mbo] 38: learning_rate=0.049; num_leaves=121; min_data_in_leaf=522; feature_fraction=0.277; min_gain_to_split=0.47 : y = 0.929 : 172.4 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Wed Nov 05 03:40:26 AM 2025 AUC 0.928037422358141
#
# [mbo] 39: learning_rate=0.08; num_leaves=256; min_data_in_leaf=299; feature_fraction=0.35; min_gain_to_split=2.44 : y = 0.928 : 174.6 secs : infill_ei
#
# Wed Nov 05 03:43:33 AM 2025 AUC 0.92988962165223
#
# [mbo] 40: learning_rate=0.0288; num_leaves=79; min_data_in_leaf=694; feature_fraction=0.373; min_gain_to_split=2.07 : y = 0.93 : 186.6 secs : infill_ei
#
# Wed Nov 05 03:46:37 AM 2025 AUC 0.930288915771113
#
# [mbo] 41: learning_rate=0.0354; num_leaves=240; min_data_in_leaf=558; feature_fraction=0.379; min_gain_to_split=1.71 : y = 0.93 : 183.6 secs : infill_ei
#
# Wed Nov 05 03:49:40 AM 2025 AUC 0.92865674594916
#
# [mbo] 42: learning_rate=0.0332; num_leaves=232; min_data_in_leaf=622; feature_fraction=0.372; min_gain_to_split=3.02 : y = 0.929 : 182.0 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Wed Nov 05 03:52:42 AM 2025 AUC 0.929972186954633
#
# [mbo] 43: learning_rate=0.0398; num_leaves=182; min_data_in_leaf=480; feature_fraction=0.365; min_gain_to_split=1.7 : y = 0.93 : 180.9 secs : infill_ei
#
# Wed Nov 05 03:56:30 AM 2025 AUC 0.930051928019367
#
# [mbo] 44: learning_rate=0.00755; num_leaves=217; min_data_in_leaf=891; feature_fraction=0.373; min_gain_to_split=1.6 : y = 0.93 : 227.9 secs : infill_ei
#
# Wed Nov 05 03:59:38 AM 2025 AUC 0.928418793334669
#
# [mbo] 45: learning_rate=0.0682; num_leaves=212; min_data_in_leaf=721; feature_fraction=0.389; min_gain_to_split=0.958 : y = 0.928 : 187.0 secs : infill_ei
#
# Wed Nov 05 04:03:43 AM 2025 AUC 0.929521869468414
#
# [mbo] 46: learning_rate=0.00533; num_leaves=225; min_data_in_leaf=701; feature_fraction=0.4; min_gain_to_split=1.95 : y = 0.93 : 244.9 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Wed Nov 05 04:07:29 AM 2025 AUC 0.929658328144683
#
# [mbo] 47: learning_rate=0.00519; num_leaves=66; min_data_in_leaf=692; feature_fraction=0.301; min_gain_to_split=1.56 : y = 0.93 : 225.3 secs : infill_ei
#
# Wed Nov 05 04:11:38 AM 2025 AUC 0.929870544899966
#
# [mbo] 48: learning_rate=0.00509; num_leaves=195; min_data_in_leaf=645; feature_fraction=0.364; min_gain_to_split=1.27 : y = 0.93 : 248.0 secs : infill_ei
#
# Wed Nov 05 04:14:43 AM 2025 AUC 0.92701964596922
#
# [mbo] 49: learning_rate=0.0397; num_leaves=203; min_data_in_leaf=1140; feature_fraction=0.386; min_gain_to_split=2.05 : y = 0.927 : 184.4 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Wed Nov 05 04:18:23 AM 2025 AUC 0.929880656822714
#
# [mbo] 50: learning_rate=0.0554; num_leaves=46; min_data_in_leaf=338; feature_fraction=0.303; min_gain_to_split=0.00406 : y = 0.93 : 219.3 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"     "num_leaves"        "min_data_in_leaf"
#  [4] "feature_fraction"  "min_gain_to_split" "y"
#  [7] "dob"               "eol"               "error.message"
# [10] "exec.time"         "ei"                "error.model"
# [13] "train.time"        "prop.type"         "propose.time"
# [16] "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves min_data_in_leaf feature_fraction min_gain_to_split
#            <num>      <int>            <int>            <num>             <num>
# 1:   0.005387282        256              340        0.2948884          1.364804
# [1] 0.9316928

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 245681
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 1.364804
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.005387282
#
# $feature_fraction
# [1] 0.2948884
#
# $num_leaves
# [1] 256
#
# $min_data_in_leaf
# [1] 340

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 05 04:25:10 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
